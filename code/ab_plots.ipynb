# %% [markdown]
# # Raincloud Plots

# %% [markdown]
# Nun können wir für jeden Knochentypen die vier häufigsten Mess-Dimensionen über die vier Perioden auswerten.
# Dazu nutzen wir Raincloud Plots, da sie einen guten Überblick sowohl über die Verteilung der Rohdaten, als auch den mean und die Ausreißer geben:

# %%
from utils import load_write as lw
from utils import plotting
import os

directory = os.fsencode("../data/csv/elements/meastypes/")

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith("_meastypes.csv"):
        bone_type = filename.split("_")[0]
        #df = lw.load_csv("../data/csv/elements/meastypes/"+filename)
        #plotting.raincloud_plot(df, bone_type)

# %% [markdown]
# # Barcharts

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")

amounts = lw.load_csv("../data/csv/amt-measures-findings.csv")

plt.figure(figsize=(8,8))

sns.barplot(x='amount', y='bone_type', hue='amt_type', data=amounts,
            ci=None)
# Out:
# <Axes: xlabel='amount', ylabel='bone_type'>
